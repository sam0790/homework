# %% [markdown]
# ### 1. Make sure you can get the API from class to work in Azure. Take a screenshot of it working and add the image to a jupyter notebook.

# %% [markdown]
# Main Index page:  https://flask-class-app.azurewebsites.net/
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# GDP page :   https://flask-class-app.azurewebsites.net/gdp
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Page with 2019 year:  https://flask-class-app.azurewebsites.net/gdp/2019
#
# ![image-2.png](attachment:image-2.png)
