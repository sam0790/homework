# %%
import pandas as pd

belize = pd.read_csv("belize_airbnb_listings.csv")

bel_df = pd.DataFrame(belize)
bel_df
# Out:
#             id                                               name    host_id  \
# 0        36666         Mo's Cozy Casa w/ veranda & access to dock     157752
# 1        36690  Mo's Cozy Cabana w/ comfy veranda & access to ...     157752
# 2       108932  Purple House eco solar  w/ ocean & wildlife views     563377
# 3       110483                            Michelo's fuchsia suite     567809
# 4       120115               Seaside Villas Second Floor Unit  #4     604999
# ...        ...                                                ...        ...
# 2791  48283996                                     Magical Island   17994012
# 2792  48287613   The Luxury Suite - Corozal, Bz- 3Bdr/2bthr CASA1  375769845
# 2793  48296096  Lagoon front apartment w/shared pool -  two mi...   76414486
# 2794  48296978                          Beachfront Poolside Condo   15308338
# 2795  48332221           Standard Room - San Ignacio Resort Hotel   60399527
#
# ...

# %%
new_bel = bel_df.groupby("neighbourhood")

new_bel.head()
# Out:
#             id                                               name    host_id  \
# 0        36666         Mo's Cozy Casa w/ veranda & access to dock     157752
# 1        36690  Mo's Cozy Cabana w/ comfy veranda & access to ...     157752
# 2       108932  Purple House eco solar  w/ ocean & wildlife views     563377
# 3       110483                            Michelo's fuchsia suite     567809
# 4       120115               Seaside Villas Second Floor Unit  #4     604999
# 5       120116                                           Valarosa     604999
# 6       124794                 Sabal Beach - secluded eco-retreat     562206
# 7       152512  Stunning one br apt-kitchen, air con, bikes & ...     733857
# 8       152922                     rent a private room in a house     735525
# 9       171294                                        King Deluxe     817242
# 10      171301                     Cabana in a Rainforest Setting     817242
# ...

# %%
meandf = new_bel['price'].mean()
total = new_bel['number_of_reviews'].sum()
ave_avail = new_bel["availability_365"].mean()

meandf.head()
# Out:
# neighbourhood
# Belize Islands     399.442824
# Belize Mainland    288.273063
# Cayo               205.847525
# Corozal            156.553846
# Orange Walk        122.035714
# Name: price, dtype: float64

# %%
total.head()
# Out:
# neighbourhood
# Belize Islands     22995
# Belize Mainland     4105
# Cayo                7356
# Corozal              492
# Orange Walk          415
# Name: number_of_reviews, dtype: int64

# %%
ave_avail.head()
# Out:
# neighbourhood
# Belize Islands     295.970837
# Belize Mainland    261.014760
# Cayo               259.249505
# Corozal            278.676923
# Orange Walk        261.928571
# Name: availability_365, dtype: float64

# %%
new_dict = {"Price": meandf, "Number of reviews": total, "Availability": ave_avail }

new_df = pd.DataFrame(new_dict)
new_df.index_reset()
new_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-22d5690ea751> in <module>
#       2
#       3 new_df = pd.DataFrame(new_dict)
# ----> 4 new_df.index_reset()
#       5 new_df
#
# c:\python\python38\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'index_reset'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x= "neighbourhood", data=)
