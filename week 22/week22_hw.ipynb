# %% [markdown]
# ### 1.	Create a python function to scrape Yelp data for 50 restaurants close to you. Think about what data you want to scrape aside from the restaurant name and location. You must pick at least three other fields. You can use beautiful soup, selenium, scrapy, and/or splinter as possible.

# %%
from bs4 import BeautifulSoup as bs
import requests


headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'}
url='https://www.yelp.com/search?cflt=restaurants&find_loc=Manchester%2C%20MO&start=10'

#     'https://www.yelp.com/search?cflt=restaurants&find_loc=Manchester%2C%20MO&start=10',
 #    'https://www.yelp.com/search?cflt=restaurants&find_loc=Manchester%2C%20MO&start=20',
  #  'https://www.yelp.com/search?cflt=restaurants&find_loc=Manchester%2C%20MO&start=30',
  #   'https://www.yelp.com/search?cflt=restaurants&find_loc=Manchester%2C%20MO&start=40']
response=requests.get(url,headers=headers)


soup=bs(response.content,'html.parser')

all_divs = soup.select('[class*=container]')


for div in all_divs:
    try:
        if item.find('h4'):
            #print(item)
            name = item.find('a',class_='css-166la90').text
            print(name)
            print(item.select('[class*=reviewCount]')[0].get_text())
            print(item.select('[aria-label*=rating]')[0]['aria-label'])
            #print(soup.select('[class*=secondaryAttributes]')[0].get_text())
            #print(item.find('span',{'class':"priceRange__09f24__2GspP css-e81eai"}).text)
            print(item.select('[class*=priceCategory]')[0].get_text())
            print('------------------')


    except Exception as e:
        raise e
        print('')
# Out:
# First Watch
# 97
# 4 star rating
# American (Traditional)Breakfast & BrunchCoffee & Tea
# ------------------
# First Watch
# 97
# 4 star rating
# American (Traditional)Breakfast & BrunchCoffee & Tea
# ------------------
# First Watch
# 97
# 4 star rating
# American (Traditional)Breakfast & BrunchCoffee & Tea
# ------------------
# First Watch
# 97
# 4 star rating
# American (Traditional)Breakfast & BrunchCoffee & Tea
# ------------------
# First Watch
# 97
# 4 star rating
# American (Traditional)Breakfast & BrunchCoffee & Tea
# ------------------
# First Watch
# 97
# 4 star rating
# American (Traditional)Breakfast & BrunchCoffee & Tea
# ------------------
# First Watch
# 97
# 4 star rating
# American (Traditional)Breakfast & BrunchCoffee & Tea
# ------------------
# First Watch
# 97
# 4 star rating
# American (Traditional)Breakfast & BrunchCoffee & Tea
# ------------------
# First Watch
# 97
# 4 star rating
# American (Traditional)Breakfast & BrunchCoffee & Tea
# ------------------
# ...

# %%
if item.find('h4'):
			name = item.find('h4').get_text()
			print(name)
			print(soup.select('[class*=reviewCount]')[0].get_text())
			print(soup.select('[aria-label*=rating]')[0]['aria-label'])
			print(soup.select('[class*=secondaryAttributes]')[0].get_text())
			print(soup.select('[class*=priceRange]')[0].get_text())
			print(soup.select('[class*=priceCategory]')[0].get_text())
			print('------------------')

# %%
from bs4 import BeautifulSoup as bs
import requests


headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'}
url='https://www.yelp.com/search?cflt=restaurants&find_loc=Manchester%2C%20MO&start=10'

#     'https://www.yelp.com/search?cflt=restaurants&find_loc=Manchester%2C%20MO&start=10',
 #    'https://www.yelp.com/search?cflt=restaurants&find_loc=Manchester%2C%20MO&start=20',
  #  'https://www.yelp.com/search?cflt=restaurants&find_loc=Manchester%2C%20MO&start=30',
  #   'https://www.yelp.com/search?cflt=restaurants&find_loc=Manchester%2C%20MO&start=40']
response=requests.get(url,headers=headers)


soup=bs(response.content,'html.parser')


for item in soup.select('[class*=container]'):
    try:
        if item.find('h4'):
            name = item.find("a",class_="css-1661a90").text
            print(name)
            #review = item.find('span', {"class":"displayreviewCount]')[0].get_text())
            #print(item.select('[aria-label*=rating]')[0]['aria-label'])
            #print(item.select('[class*=priceRange]')[0].get_text())
            #print(item.select('[class*=priceCategory]')[0].get_text())
            print('------------------')
            
    except Exception as e:
        raise e
        print('')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-5425ec5da0dc> in <module>
#      28
#      29     except Exception as e:
# ---> 30         raise e
#      31         print('')
#
# <ipython-input-5-5425ec5da0dc> in <module>
#      19     try:
#      20         if item.find('h4'):
# ---> 21             name = item.find("a",class_="css-1661a90").text
#      22             print(name)
#      23             #review = item.find('span', {"class":"displayreviewCount]')[0].get_text())
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# ### 2.	Create an API that calls your scrape function and stores the data when you call /scrape endpoint. The data you scrape should be viewable when you go to /all .
#
# a.	If you have time, you can work on getting this to work in Azure, but there is a bit more complexity than we discussed depending on which modules you used.

# %% [markdown]
# ### 3.	What is web scraping? Why is it helpful? Why is it sometimes in a legal grey area?
