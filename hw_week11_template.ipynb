# %% [markdown]
# # Homework

# %%
#Handy imports from class

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import plotly.express as px
from scipy import signal

df = pd.read_csv('temperature.csv')


df.head()
# Out:
#               datetime   Vancouver    Portland  San Francisco     Seattle  \
# 0  2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 1  2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2  2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3  2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 4  2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
#
#    Los Angeles   San Diego   Las Vegas     Phoenix  Albuquerque  ...  \
# 0          NaN         NaN         NaN         NaN          NaN  ...
# 1   291.870000  291.530000  293.410000  296.600000   285.120000  ...
# 2   291.868186  291.533501  293.403141  296.608509   285.154558  ...
# 3   291.862844  291.543355  293.392177  296.631487   285.233952  ...
# 4   291.857503  291.553209  293.381213  296.654466   285.313345  ...
#
#    Philadelphia    New York    Montreal      Boston   Beersheba  \
# 0           NaN         NaN         NaN         NaN         NaN
# 1    285.630000  288.220000  285.830000  287.170000  307.590000
# 2    285.663208  288.247676  285.834650  287.186092  307.590000
# 3    285.756824  288.326940  285.847790  287.231672  307.391513
# 4    285.850440  288.406203  285.860929  287.277251  307.145200
#
#    Tel Aviv District       Eilat  Haifa  Nahariyya  Jerusalem
# 0                NaN  309.100000    NaN        NaN        NaN
# 1         305.470000  310.580000  304.4      304.4      303.5
# 2         304.310000  310.495769  304.4      304.4      303.5
# 3         304.281841  310.411538  304.4      304.4      303.5
# 4         304.238015  310.327308  304.4      304.4      303.5
#
# [5 rows x 37 columns]

# %% [markdown]
# ### 1. Write a function that efficiently converts every column to a different temperature scale

# %%
def to_fahrenheit(x):
    
    if x == 'NaN':
        return x 
    else:
        x = float(x)
        y = (1.8*(x - 273.15)) + 32
        return y


df1 = df.iloc[:,1:]
#empty dataframe
df2 = pd.DataFrame()

for i in range(len(df1.axes[1])):
    
    df_for = df1.iloc[:,(i)].apply(to_fahrenheit)
    df2 = df2.append(df_for)
    

df_F = df2.T

df_F['datetime'] = df['datetime']



df_F
#df_F.iloc[:,-1]

#k = df_F.loc[~df_F.iloc[:,1].isnull()]
#k
#df_F
# Out:
#        Vancouver   Portland  San Francisco    Seattle  Los Angeles  San Diego  \
# 0            NaN        NaN            NaN        NaN          NaN        NaN
# 1      52.664000  48.074000      61.394000  47.570000    65.696000  65.084000
# 2      52.662274  48.079854      61.384987  47.564990    65.692734  65.090302
# 3      52.658596  48.095360      61.359113  47.551699    65.683120  65.108039
# 4      52.654918  48.110866      61.333238  47.538407    65.673506  65.125777
# ...          ...        ...            ...        ...          ...        ...
# 45248        NaN  47.930000            NaN  45.806000    68.720000  66.200000
# 45249        NaN  49.532000            NaN  47.300000    72.554000  67.262000
# 45250        NaN  50.432000            NaN  49.280000    73.058000  66.974000
# 45251        NaN  49.766000            NaN  49.658000    72.500000  67.028000
# 45252        NaN  48.434000            NaN  49.802000    71.204000  64.850000
#
#        Las Vegas    Phoenix  Albuquerque     Denver  ...   New York  \
# 0            NaN        NaN          NaN        NaN  ...        NaN
# 1      68.468000  74.210000    53.546000  52.628000  ...  59.126000
# 2      68.455654  74.225315    53.608205  52.623150  ...  59.175817
# 3      68.435919  74.266677    53.751113  52.609852  ...  59.318491
# 4      68.416183  74.308039    53.894021  52.596554  ...  59.461166
# ...          ...        ...          ...        ...  ...        ...
# 45248  61.502000  70.808000    54.626000  61.538000  ...        NaN
# 45249  63.428000  72.392000    55.940000  63.590000  ...        NaN
# 45250  64.742000  73.580000    55.922000  61.808000  ...        NaN
# 45251  66.200000  75.200000    55.382000  60.836000  ...        NaN
# 45252  65.282000  75.200000    52.790000  53.654000  ...        NaN
#
#         Montreal     Boston  Beersheba  Tel Aviv District      Eilat  Haifa  \
# 0            NaN        NaN        NaN                NaN  96.710000    NaN
# 1      54.824000  57.236000  93.992000          90.176000  99.374000  88.25
# 2      54.832370  57.264966  93.992000          88.088000  99.222385  88.25
# 3      54.856021  57.347009  93.634723          88.037314  99.070769  88.25
# 4      54.879672  57.429052  93.191359          87.958426  98.919154  88.25
# ...          ...        ...        ...                ...        ...    ...
# 45248  35.564000  58.874000        NaN                NaN        NaN    NaN
# 45249  33.764000  55.166000        NaN                NaN        NaN    NaN
# 45250  32.594000  51.422000        NaN                NaN        NaN    NaN
# 45251  30.794000  48.236000        NaN                NaN        NaN    NaN
# 45252  29.570000  45.500000        NaN                NaN        NaN    NaN
#
#        Nahariyya  Jerusalem             datetime
# 0            NaN        NaN  2012-10-01 12:00:00
# 1          88.25      86.63  2012-10-01 13:00:00
# 2          88.25      86.63  2012-10-01 14:00:00
# 3          88.25      86.63  2012-10-01 15:00:00
# 4          88.25      86.63  2012-10-01 16:00:00
# ...          ...        ...                  ...
# 45248        NaN        NaN  2017-11-29 20:00:00
# 45249        NaN        NaN  2017-11-29 21:00:00
# 45250        NaN        NaN  2017-11-29 22:00:00
# 45251        NaN        NaN  2017-11-29 23:00:00
# 45252        NaN        NaN  2017-11-30 00:00:00
#
# [45253 rows x 37 columns]

# %%
df_for = df1.iloc[:,(1)].apply(to_fahrenheit)
#df4 = df2.append(df_f)
#len(df_F.axes[1])

k = df_F.loc[~df_F.iloc[1].isnull(),[df_F.iloc[-1],df_F.iloc[:,1]]]
k
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-193-29a6c2992490> in <module>
#       3 #len(df_F.axes[1])
#       4
# ----> 5 k = df_F.loc[~df_F.iloc[1].isnull(),[df_F.iloc[-1],df_F.iloc[:,1]]]
#       6 k
#
# c:\python\python38\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# c:\python\python38\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1067             return self._multi_take(tup)
#    1068
# -> 1069         return self._getitem_tuple_same_dim(tup)
#    1070
#    1071     def _get_label(self, label, axis: int):
#
# c:\python\python38\lib\site-packages\pandas\core\indexing.py in _getitem_tuple_same_dim(self, tup)
#     773                 continue
#     774
# --> 775             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     776             # We should never have retval.ndim < self.ndim, as that should
#     777             #  be handled by the _getitem_lowerdim call above.
#
# c:\python\python38\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1102             return self._get_slice_axis(key, axis=axis)
#    1103         elif com.is_bool_indexer(key):
# -> 1104             return self._getbool_axis(key, axis=axis)
#    1105         elif is_list_like_indexer(key):
#    1106
#
# c:\python\python38\lib\site-packages\pandas\core\indexing.py in _getbool_axis(self, key, axis)
#     910         # caller is responsible for ensuring non-None axis
#     911         labels = self.obj._get_axis(axis)
# --> 912         key = check_bool_indexer(labels, key)
#     913         inds = key.nonzero()[0]
#     914         return self.obj._take_with_is_copy(inds, axis=axis)
#
# c:\python\python38\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2267         mask = isna(result._values)
#    2268         if mask.any():
# -> 2269             raise IndexingError(
#    2270                 "Unalignable boolean Series provided as "
#    2271                 "indexer (index of the boolean Series and of "
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %% [markdown]
# ### 2. Write a function that efficiently fills in missing values in every column, except for trailing NANs.
#
# That is: if there's temperature data on either side of a timestamp, it should interpolate through it. But if data stopped being collected, your function should leave nans at the end

# %%
def value_N(a):
    
    #x = a.iloc[:,-1]
    df_N = pd.DataFrame()
    
        

    for column in a:
        columnSeriesObj = a[column]
        val = pd.DataFrame(columnSeriesObj.values)
        x = a.iloc[:,-1]
       
        k = ~val.isnull()
        xp = k[x]
        fp = k[columnSeriesObj.values]
        data = np.interp(x,xp,fp)
        
        df_N = df_N.append(data)
        
        
value_N(df_F)

     for column in a:
        
        columnSeriesObj = a[column]
        new = pd.DataFrame(columnSeriesObj.values, columns = column)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-86dbe68124b7> in <module>
#      19
#      20
# ---> 21 value_N(df_F)
#      22
#      23
#
# <ipython-input-48-86dbe68124b7> in value_N(a)
#      13         k = ~val.isnull()
#      14         #xp = k[x]
# ---> 15         fp = k[columnSeriesObj.values]
#      16         data = np.interp(x,xp,fp)
#      17
#
# c:\python\python38\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# c:\python\python38\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# c:\python\python38\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Float64Index([               nan,  52.66400000000003, 52.662274358000026,\n                   52.6585962614,  52.65491816299999,  52.65124006460009,\n               52.64756196620008,  52.64388386780007,  52.64020576940007,\n               52.63652767100005,\n              ...\n                             nan,                nan,                nan,\n                             nan,                nan,                nan,\n                             nan,                nan,                nan,\n                             nan],\n             dtype='float64', length=45253)] are in the [columns]"

# %%
def value_N(a):
    
    df_N = pd.DataFrame()
    
    for column in a:
        columnSeriesObj = a[column]
        
        x = a.iloc[:,-1]
        k = a.loc[~a.iloc[column].isnull(),[x,column]]
        xp = k[x]
        fp = np.array(k[column])
        
        t = pd.DataFrame({'$x$': x , '$column$': np.interp(x,xp,fp)})
        
        df_N = df_N.append(t)


value_N(df_F)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-117263e92013> in <module>
#      16
#      17
# ---> 18 value_N(df_F)
#      19
#      20
#
# <ipython-input-49-117263e92013> in value_N(a)
#       7
#       8         x = a.iloc[:,-1]
# ----> 9         k = a.loc[~a.iloc[column].isnull(),[x,column]]
#      10         xp = k[x]
#      11         fp = np.array(k[column])
#
# c:\python\python38\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# c:\python\python38\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1496             key = item_from_zerodim(key)
#    1497             if not is_integer(key):
# -> 1498                 raise TypeError("Cannot index by location index with a non-integer key")
#    1499
#    1500             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %% [markdown]
# $ Markdown $
#
# LateX: $\alpha^2$

# %%
for i in range(len(a.axes[1])):
        k = a.loc[~a[i].isnull(),[x,a.iloc[:,i]]]
        xp = k[a.iloc[:,-1]]
        fp = np.array(k[a.iloc[:,i]])
        
        data = np.interp(x,xp,fp)
        df_N = df_N.append(x,data)
        print(df_N
              
              
              
x = df['datetime']
knowns = df.loc[~df['Vancouver'].isnull(), ['datetime','Vancouver']]
xp = knowns['datetime']
fp = np.array(knowns['Vancouver'])

test = pd.DataFrame({'datetime':x, 'Vancouver': np.interp(x, xp, fp)})

# %% [markdown]
# ### 3. Find cities A and B where city A is warmer than city B in the summer, but also colder than city B in the winter, on average

# %% [markdown]
# ### 4. For the two cities you found in for problem 4 (there are many possible answers), clean up the data via aggregation or rolling averages and plot a clear visual
